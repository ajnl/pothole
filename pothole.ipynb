# %% [markdown]
# <a href="https://colab.research.google.com/github/ajnl/pothole/blob/main/pothole.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !pip install ultralytics
# Out:
# /content
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="7TQjINczo2Lqo5YpBt40")
project = rf.workspace("ws1-0s0rn").project("pothole-detection-xeayd")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from ultralytics import YOLO

# Load a pre-trained YOLO model (you can choose n, s, m, l, or x versions)
model = YOLO("yolo11n.pt")

# Start training on your custom dataset
model.train(data="/content/Pothole-Detection-1/data.yaml", epochs=100, imgsz=640)
# Out:
# Ultralytics 8.3.80 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/yolo11n.pt")  # load an official model
model = YOLO("/content/runs/detect/train/weights/best.pt")  # load a custom trained model

# Export the model
model.export(format="onnx")
# Out:
# Ultralytics 8.3.80 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.30GHz)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from '/content/runs/detect/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (5.2 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.48...
# ONNX: export success ✅ 1.4s, saved as '/content/runs/detect/train/weights/best.onnx' (10.1 MB)
#
# Export complete (1.9s)
# Results saved to /content/runs/detect/train/weights
# Predict:         yolo predict task=detect model=/content/runs/detect/train/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=/content/runs/detect/train/weights/best.onnx imgsz=640 data=/content/Pothole-Detection-1/data.yaml
# Visualize:       https://netron.app
# '/content/runs/detect/train/weights/best.onnx'

# %%
import os
from ultralytics import YOLO

model = YOLO("/content/runs/detect/train/weights/best.pt")

# Process all images in the folder
for img in filter(lambda f: f.lower().endswith(('.png', '.jpg', '.jpeg')), os.listdir("Pothole-Detection-1/test/images")):
    for r in model(os.path.join("Pothole-Detection-1/test/images", img)):
        r.show()  # Display detection results
# Out:
# image 1/1 /content/Pothole-Detection-1/test/images/img-19_jpg.rf.b248bdb2849154bd25a782bddacfbc82.jpg: 640x640 1 pothole, 14.6ms
# Speed: 2.2ms preprocess, 14.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=640x640>
# image 1/1 /content/Pothole-Detection-1/test/images/img-2_jpg.rf.22aa30ccf97f9fca4c544b919a35caef.jpg: 640x640 1 pothole, 14.8ms
# Speed: 2.7ms preprocess, 14.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=640x640>

# %% [markdown]
# import os
# import shutil
#
# predict_path = "/content/runs/detect"
# if os.path.exists(predict_path):
#     shutil.rmtree(predict_path)
#     print("Deleted previous predictions.")
# else:
#     print("No previous predictions found.")

# %%
# Zip the Folder in Google Colab
# !zip -r content.zip /content
# Out:
#   adding: content/ (stored 0%)
#   adding: content/.config/ (stored 0%)
#   adding: content/.config/hidden_gcloud_config_universe_descriptor_data_cache_configs.db (deflated 97%)
#   adding: content/.config/.last_survey_prompt.yaml (stored 0%)
#   adding: content/.config/config_sentinel (stored 0%)
#   adding: content/.config/.last_opt_in_prompt.yaml (stored 0%)
#   adding: content/.config/logs/ (stored 0%)
#   adding: content/.config/logs/2025.03.04/ (stored 0%)
#   adding: content/.config/logs/2025.03.04/14.25.56.762625.log (deflated 57%)
#   adding: content/.config/logs/2025.03.04/14.26.19.384068.log (deflated 57%)
#   adding: content/.config/logs/2025.03.04/14.26.20.076126.log (deflated 56%)
#   adding: content/.config/logs/2025.03.04/14.26.05.979204.log (deflated 86%)
#   adding: content/.config/logs/2025.03.04/14.26.10.758958.log (deflated 58%)
#   adding: content/.config/logs/2025.03.04/14.25.29.484800.log (deflated 92%)
#   adding: content/.config/active_config (stored 0%)
# ...
